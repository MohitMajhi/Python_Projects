# %%
# !docker build -t f_app:v1 .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 146B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11             0.1s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 146B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11             0.3s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 146B                                       0.0s
# ...

# %%
# !docker images
# Out:
# REPOSITORY                    TAG       IMAGE ID       CREATED        SIZE
# mohitmajhi/helm-flask         v1        78422113aa20   2 weeks ago    1.12GB
# jenkins/jenkins               lts       59bc435e1f03   4 weeks ago    491MB
# gcr.io/k8s-minikube/kicbase   v0.0.48   c6b5532e987b   5 months ago   1.31GB
# harness/harness               latest    57a12ee89574   6 months ago   223MB
# drone/git                     latest    b263385b74bd   3 years ago    198MB

# %%
# !docker login

# %%
# !docker tag f_app:v1 mohitmajhi/helm-flask:v1

# %%
# !docker push mohitmajhi/helm-flask:v1

# %%
# !docker pull mohitmajhi/helm-flask:v1
